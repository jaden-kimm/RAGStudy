# %%
from dotenv import load_dotenv
from langchain_teddynote import logging
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate

load_dotenv()
logging.langsmith("CH02-Prmopt")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# CH02-Prmopt

# %% [markdown]
# ## LLM 설정

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.5)

# %% [markdown]
# ## PromptTemplate 설정

# %%
template = """Where is the capital city of {country}?"""

prompt = PromptTemplate.from_template(template)

# %%
prompt_example = prompt.format(country="Korea")
print(prompt_example)
# Out:
# Where is the capital city of Korea?

# %%
chain = prompt | llm
chain.invoke("Korea")
# Out:
# AIMessage(content="The capital city of South Korea is Seoul. North Korea's capital is Pyongyang.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 15, 'total_tokens': 33, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b547601dbd', 'id': 'chatcmpl-Ch6EChQ0EbUpvgEi8ZHjx75U8Rl1o', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--f1d998f8-2c44-4035-a9f1-300c08edb46d-0', usage_metadata={'input_tokens': 15, 'output_tokens': 18, 'total_tokens': 33, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
## prompt template 객체 생성하는 another method
template = "{country}의 수도는 어디인가요?"

prompt = PromptTemplate(
    template = template,
    input_variables=["country"],
)

print(prompt)
print("=" * 20)
print(prompt.format(country="South Korea"))
# Out:
# input_variables=['country'] input_types={} partial_variables={} template='{country}의 수도는 어디인가요?'
# ====================
# South Korea의 수도는 어디인가요?
