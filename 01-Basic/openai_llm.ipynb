# %%
from dotenv import load_dotenv

load_dotenv()  # Load environment variables from .env file
# Out:
# True

# %%
from langchain_teddynote import logging

# Write Project name
logging.langsmith("CH01-Basic")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# CH01-Basic

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.2
)

query = "Where is the capital of Korea?"

response = llm.invoke(query)

print(response.content)
print("=" * 50)
print(response.response_metadata)
print("=" * 50)
print(response.response_metadata["token_usage"])
# Out:
# The capital of South Korea is Seoul, while the capital of North Korea is Pyongyang.
# ==================================================
# {'token_usage': {'completion_tokens': 19, 'prompt_tokens': 14, 'total_tokens': 33, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CZrd3kavoVln7AvES2IjfXQjmcMUg', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}
# ==================================================
# {'completion_tokens': 19, 'prompt_tokens': 14, 'total_tokens': 33, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}

# %%
# logprob
llm_with_logprob = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.2,
    max_tokens=1024
).bind(logprobs=True)

query="where is the capital of Japan?"
response = llm_with_logprob.invoke(query)
print(response.response_metadata["logprobs"])
# Out:
# {'content': [{'token': 'The', 'bytes': [84, 104, 101], 'logprob': -4.320199877838604e-07, 'top_logprobs': []}, {'token': ' capital', 'bytes': [32, 99, 97, 112, 105, 116, 97, 108], 'logprob': 0.0, 'top_logprobs': []}, {'token': ' of', 'bytes': [32, 111, 102], 'logprob': 0.0, 'top_logprobs': []}, {'token': ' Japan', 'bytes': [32, 74, 97, 112, 97, 110], 'logprob': 0.0, 'top_logprobs': []}, {'token': ' is', 'bytes': [32, 105, 115], 'logprob': 0.0, 'top_logprobs': []}, {'token': ' Tokyo', 'bytes': [32, 84, 111, 107, 121, 111], 'logprob': -0.00019829542725346982, 'top_logprobs': []}, {'token': '.', 'bytes': [46], 'logprob': -7.896309739408025e-07, 'top_logprobs': []}], 'refusal': None}

# %%
# Streaming
answer = llm.stream("대한민국의 아름다운 관광지 10곳과 주소를 알려주세요")

for token in answer:
    print(token.content, end="", flush=True)
